# %%
import time
import schedule
import datetime
import subprocess

# %%
def timed_command():
    command = "bash /pinky/patrick/birdclips/scripts/pics_benchmark_script.sh"
    process = subprocess.Popen(command.split(), stdout=subprocess.PIPE)
    output, error = process.communicate()

# %%
schedule.every().day.at("11:32").do(timed_command)
schedule.every().day.at("11:37").do(timed_command)
schedule.every().day.at("11:42").do(timed_command)
schedule.every().day.at("11:47").do(timed_command)
schedule.every().day.at("11:52").do(timed_command)
schedule.every().day.at("11:57").do(timed_command)
schedule.every().day.at("12:02").do(timed_command)
schedule.every().day.at("12:07").do(timed_command)
schedule.every().day.at("12:12").do(timed_command)
schedule.every().day.at("12:17").do(timed_command)
schedule.every().day.at("12:22").do(timed_command)
schedule.every().day.at("12:27").do(timed_command)
schedule.every().day.at("12:32").do(timed_command)
schedule.every().day.at("12:37").do(timed_command)
schedule.every().day.at("12:42").do(timed_command)
schedule.every().day.at("12:47").do(timed_command)
schedule.every().day.at("12:52").do(timed_command)
schedule.every().day.at("12:57").do(timed_command)
schedule.every().day.at("13:02").do(timed_command)
schedule.every().day.at("13:07").do(timed_command)
schedule.every().day.at("13:12").do(timed_command)
schedule.every().day.at("13:17").do(timed_command)
schedule.every().day.at("13:22").do(timed_command)
schedule.every().day.at("13:27").do(timed_command)
schedule.every().day.at("13:32").do(timed_command)
schedule.every().day.at("13:37").do(timed_command)
schedule.every().day.at("13:42").do(timed_command)
schedule.every().day.at("13:47").do(timed_command)
schedule.every().day.at("13:52").do(timed_command)
schedule.every().day.at("13:57").do(timed_command)
schedule.every().day.at("14:02").do(timed_command)
schedule.every().day.at("14:07").do(timed_command)
schedule.every().day.at("14:12").do(timed_command)
schedule.every().day.at("14:17").do(timed_command)
schedule.every().day.at("14:22").do(timed_command)
schedule.every().day.at("14:27").do(timed_command)
schedule.every().day.at("14:32").do(timed_command)
schedule.every().day.at("14:37").do(timed_command)
schedule.every().day.at("14:42").do(timed_command)
schedule.every().day.at("14:47").do(timed_command)
schedule.every().day.at("14:52").do(timed_command)
schedule.every().day.at("14:57").do(timed_command)
schedule.every().day.at("15:02").do(timed_command)
schedule.every().day.at("15:07").do(timed_command)
schedule.every().day.at("15:12").do(timed_command)
schedule.every().day.at("15:17").do(timed_command)
schedule.every().day.at("15:22").do(timed_command)
schedule.every().day.at("15:27").do(timed_command)
schedule.every().day.at("15:32").do(timed_command)
schedule.every().day.at("15:37").do(timed_command)
schedule.every().day.at("15:42").do(timed_command)
schedule.every().day.at("15:47").do(timed_command)
schedule.every().day.at("15:52").do(timed_command)
schedule.every().day.at("15:57").do(timed_command)
schedule.every().day.at("16:02").do(timed_command)
schedule.every().day.at("16:07").do(timed_command)
schedule.every().day.at("16:12").do(timed_command)
schedule.every().day.at("16:17").do(timed_command)
schedule.every().day.at("16:22").do(timed_command)
schedule.every().day.at("16:27").do(timed_command)
schedule.every().day.at("16:32").do(timed_command)
schedule.every().day.at("16:37").do(timed_command)
schedule.every().day.at("16:42").do(timed_command)
schedule.every().day.at("16:47").do(timed_command)
schedule.every().day.at("16:52").do(timed_command)
schedule.every().day.at("16:57").do(timed_command)
schedule.every().day.at("17:02").do(timed_command)
schedule.every().day.at("17:07").do(timed_command)
schedule.every().day.at("17:12").do(timed_command)
schedule.every().day.at("17:17").do(timed_command)
schedule.every().day.at("17:22").do(timed_command)
schedule.every().day.at("17:27").do(timed_command)
schedule.every().day.at("17:32").do(timed_command)
schedule.every().day.at("17:37").do(timed_command)
schedule.every().day.at("17:42").do(timed_command)
schedule.every().day.at("17:47").do(timed_command)
schedule.every().day.at("17:52").do(timed_command)
schedule.every().day.at("17:57").do(timed_command)
schedule.every().day.at("18:02").do(timed_command)
schedule.every().day.at("18:07").do(timed_command)
schedule.every().day.at("18:12").do(timed_command)
schedule.every().day.at("18:17").do(timed_command)
schedule.every().day.at("18:22").do(timed_command)
schedule.every().day.at("18:27").do(timed_command)
schedule.every().day.at("18:32").do(timed_command)
schedule.every().day.at("18:37").do(timed_command)
schedule.every().day.at("18:42").do(timed_command)
schedule.every().day.at("18:47").do(timed_command)
schedule.every().day.at("18:52").do(timed_command)
schedule.every().day.at("18:57").do(timed_command)
schedule.every().day.at("19:02").do(timed_command)
schedule.every().day.at("19:07").do(timed_command)
schedule.every().day.at("19:12").do(timed_command)
schedule.every().day.at("19:17").do(timed_command)
schedule.every().day.at("19:22").do(timed_command)
schedule.every().day.at("19:27").do(timed_command)
schedule.every().day.at("19:32").do(timed_command)
schedule.every().day.at("19:37").do(timed_command)
schedule.every().day.at("19:42").do(timed_command)
schedule.every().day.at("19:47").do(timed_command)
schedule.every().day.at("19:52").do(timed_command)
schedule.every().day.at("19:57").do(timed_command)
schedule.every().day.at("20:02").do(timed_command)
schedule.every().day.at("20:07").do(timed_command)
schedule.every().day.at("20:12").do(timed_command)
schedule.every().day.at("20:17").do(timed_command)
schedule.every().day.at("20:22").do(timed_command)
schedule.every().day.at("20:27").do(timed_command)
schedule.every().day.at("20:32").do(timed_command)
schedule.every().day.at("20:37").do(timed_command)
schedule.every().day.at("20:4").do(timed_command)
schedule.every().day.at("20:45").do(timed_command)
schedule.every().day.at("20:50").do(timed_command)
schedule.every().day.at("20:55").do(timed_command)
schedule.every().day.at("21:00").do(timed_command)
schedule.every().day.at("21:05").do(timed_command)
schedule.every().day.at("21:10").do(timed_command)
schedule.every().day.at("21:15").do(timed_command)
schedule.every().day.at("21:20").do(timed_command)
schedule.every().day.at("21:25").do(timed_command)
schedule.every().day.at("21:30").do(timed_command)
schedule.every().day.at("21:35").do(timed_command)
schedule.every().day.at("21:40").do(timed_command)
schedule.every().day.at("21:45").do(timed_command)
schedule.every().day.at("21:50").do(timed_command)
schedule.every().day.at("21:55").do(timed_command)
schedule.every().day.at("22:00").do(timed_command)
schedule.every().day.at("22:05").do(timed_command)
schedule.every().day.at("22:10").do(timed_command)
schedule.every().day.at("22:15").do(timed_command)
schedule.every().day.at("22:20").do(timed_command)
schedule.every().day.at("22:25").do(timed_command)
schedule.every().day.at("22:30").do(timed_command)
schedule.every().day.at("22:35").do(timed_command)
schedule.every().day.at("22:40").do(timed_command)
schedule.every().day.at("22:45").do(timed_command)
schedule.every().day.at("22:50").do(timed_command)
schedule.every().day.at("22:55").do(timed_command)
schedule.every().day.at("23:00").do(timed_command)
schedule.every().day.at("23:05").do(timed_command)
schedule.every().day.at("23:10").do(timed_command)
schedule.every().day.at("23:15").do(timed_command)
schedule.every().day.at("23:20").do(timed_command)
schedule.every().day.at("23:25").do(timed_command)
schedule.every().day.at("23:30").do(timed_command)
schedule.every().day.at("23:35").do(timed_command)
schedule.every().day.at("23:40").do(timed_command)
schedule.every().day.at("23:45").do(timed_command)
schedule.every().day.at("23:50").do(timed_command)
schedule.every().day.at("23:55").do(timed_command)
schedule.every().day.at("00:00").do(timed_command)
schedule.every().day.at("00:05").do(timed_command)
schedule.every().day.at("00:10").do(timed_command)
schedule.every().day.at("00:15").do(timed_command)
schedule.every().day.at("00:20").do(timed_command)
schedule.every().day.at("00:25").do(timed_command)
schedule.every().day.at("00:30").do(timed_command)


while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-759cdcd18394> in <module>
#      53 while True:
#      54     schedule.run_pending()
# ---> 55     time.sleep(1)
#
# KeyboardInterrupt:
